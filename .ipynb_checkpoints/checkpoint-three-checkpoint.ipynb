# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset: https://www.kaggle.com/datasets/thedevastator/hospitals-in-the-united-states-a-comprehensive-d?select=hospital_locations.csv
#
# Import the necessary libraries and create your dataframe(s).

# %%
# import libraries and dataframes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\holme\OneDrive\Desktop\LaunchCode\Final Graded Assignment\Hospital_General_Information.csv")
df.head(2)
# Out:
#    index  Provider ID                  Hospital Name  \
# 0      0        10005  MARSHALL MEDICAL CENTER SOUTH
# 1      1        10032               WEDOWEE HOSPITAL
#
#                       Address     City State  ZIP Code County Name  \
# 0  2505 U S HIGHWAY 431 NORTH     BOAZ    AL     35957    MARSHALL
# 1       209 NORTH MAIN STREET  WEDOWEE    AL     36278    RANDOLPH
#
#    Phone Number         Hospital Type  ...  \
# 0    2565938310  Acute Care Hospitals  ...
# 1    2563572111  Acute Care Hospitals  ...
#
#   Readmission national comparison footnote  \
# 0                                      NaN
# 1                                      NaN
#
#    Patient experience national comparison  \
# 0            Same as the National average
# 1                           Not Available
#
#      Patient experience national comparison footnote  \
# 0                                                NaN
# 1  Results are not available for this reporting p...
#
# ...

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
# Checking for any columns that have nulls
df.isnull().any()
#  I do see Nulls, I will address this later once I determine which columns I need for my analysis
# Out:
# index                                                            False
# Provider ID                                                      False
# Hospital Name                                                    False
# Address                                                          False
# City                                                             False
# State                                                            False
# ZIP Code                                                         False
# County Name                                                       True
# Phone Number                                                     False
# Hospital Type                                                    False
# Hospital Ownership                                               False
# Emergency Services                                               False
# Meets criteria for meaningful use of EHRs                         True
# ...

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
#  There is no irregular data that I need to deal with.

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
# Checking for duplicates
df.duplicated().sum() # No duplicates
# Out:
# np.int64(0)

# %%
# List of columns to drop (these are unnecessary for my analysis)
drop_columns = [ 
"index",
"County Name",
"Meets criteria for meaningful use of EHRs",
"Hospital overall rating footnote",
"Mortality national comparison",
"Mortality national comparison footnote",
"Safety of care national comparison",
"Safety of care national comparison footnote",
"Readmission national comparison",
"Readmission national comparison footnote",
"Patient experience national comparison",
"Patient experience national comparison footnote",
"Effectiveness of care national comparison",
"Effectiveness of care national comparison footnote",
"Timeliness of care national comparison",
"Timeliness of care national comparison footnote",
"Efficient use of medical imaging national comparison",   
"Efficient use of medical imaging national comparison footnote",
"Location"]
df = df.drop(columns = drop_columns)
df
# Out:
#       Provider ID                       Hospital Name  \
# 0           10005       MARSHALL MEDICAL CENTER SOUTH
# 1           10032                    WEDOWEE HOSPITAL
# 2           10131            CRESTWOOD MEDICAL CENTER
# 3           20001    PROVIDENCE ALASKA MEDICAL CENTER
# 4           20018  YUKON KUSKOKWIM DELTA REG HOSPITAL
# ...           ...                                 ...
# 4813       501333  KITTITAS VALLEY COMMUNITY HOSPITAL
# 4814       450827         KELL WEST REGIONAL HOSPITAL
# 4815       501310          NEWPORT COMMUNITY HOSPITAL
# 4816       670107     BAYLOR EMERGENCY MEDICAL CENTER
# 4817       450213            UNIVERSITY HEALTH SYSTEM
#
#                             Address           City State  ZIP Code  \
# 0        2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957
# 1             209 NORTH MAIN STREET        WEDOWEE    AL     36278
# 2                ONE HOSPITAL DR SE     HUNTSVILLE    AL     35801
# ...

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
# Checking format of phone number
print(df['Phone Number'].head()) # Need to format
# Covert 'Phone Number' columns into string. This allows me to be able to change format using "Lambda"
df['Phone Number'] = df['Phone Number'].apply(lambda x: str(x))
#  Format 'Phone Number' column to include "-" using "Lambda" function
df['Phone Number'] = df['Phone Number'].apply(lambda x: x[0:3] + "-" + x[3:6] + "-" + x[6:10])
df.head()
# Out:
# 0    2565938310
# 1    2563572111
# 2    2568823100
# 3    9072123675
# 4    9075436300
# Name: Phone Number, dtype: int64
#    Provider ID                       Hospital Name  \
# 0        10005       MARSHALL MEDICAL CENTER SOUTH
# 1        10032                    WEDOWEE HOSPITAL
# 2        10131            CRESTWOOD MEDICAL CENTER
# 3        20001    PROVIDENCE ALASKA MEDICAL CENTER
# 4        20018  YUKON KUSKOKWIM DELTA REG HOSPITAL
#
#                       Address        City State  ZIP Code  Phone Number  \
# 0  2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957  256-593-8310
# 1       209 NORTH MAIN STREET     WEDOWEE    AL     36278  256-357-2111
# 2          ONE HOSPITAL DR SE  HUNTSVILLE    AL     35801  256-882-3100
# 3                  BOX 196604   ANCHORAGE    AK     99508  907-212-3675
# 4                  PO BOX 287      BETHEL    AK     99559  907-543-6300
#
#           Hospital Type                           Hospital Ownership  \
# ...

# %%
# Checking for any columns that have nulls
print(df.isnull().any()) # I will need to deal with Nulls in the "Hospital overall rating" column
# Out:
# Provider ID                False
# Hospital Name              False
# Address                    False
# City                       False
# State                      False
# ZIP Code                   False
# Phone Number               False
# Hospital Type              False
# Hospital Ownership         False
# Emergency Services         False
# Hospital overall rating     True
# dtype: bool

# %%
#  will fill in remaining Nulls by changing them to blank
df = df.fillna("")
df.head(10)
# Out:
#    Provider ID                               Hospital Name  \
# 0        10005               MARSHALL MEDICAL CENTER SOUTH
# 1        10032                            WEDOWEE HOSPITAL
# 2        10131                    CRESTWOOD MEDICAL CENTER
# 3        20001            PROVIDENCE ALASKA MEDICAL CENTER
# 4        20018          YUKON KUSKOKWIM DELTA REG HOSPITAL
# 5        21309                          KANAKANAK HOSPITAL
# 6        21310                      MANIILAQ HEALTH CENTER
# 7        30071               FORT DEFIANCE INDIAN HOSPITAL
# 8        30073  TUBA CITY REGIONAL HEALTH CARE CORPORATION
# 9        30074        SELLS INDIAN HEALTH SERVICE HOSPITAL
#
#                       Address           City State  ZIP Code  Phone Number  \
# 0  2505 U S HIGHWAY 431 NORTH           BOAZ    AL     35957  256-593-8310
# 1       209 NORTH MAIN STREET        WEDOWEE    AL     36278  256-357-2111
# 2          ONE HOSPITAL DR SE     HUNTSVILLE    AL     35801  256-882-3100
# ...

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset?
# I found all, but I didn't come across Irregular Data.
#
# 2. Did the process of cleaning your data give you new insights into your dataset?
# Yes, it did. I realized that there was a lot of information that was not needed.
#
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?
# I would like to group the hospitals by "Zip Code" and "Hospital Type", then rank them by "Hospital overall rating"

# %%
# Save the DataFrame as a CSV
df.to_csv('Cleaned_Hospital_DF.csv', index = False)
